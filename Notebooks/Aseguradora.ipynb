# %% [markdown]
# <a href="https://colab.research.google.com/github/AlexisG81/etl-data-pipeline/blob/main/Notebooks/Aseguradora.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
url = "https://raw.githubusercontent.com/AlexisG81/etl-data-pipeline/refs/heads/main/data/raw/aseguradoras.csv"

# %%
df = pd.read_csv(url)

# %%
df.head()
# Out:
#    id_aseguradora         nombre         pais rating_riesgo
# 0               1  Aseguradora 1   Costa Rica          Alto
# 1               2  Aseguradora 2  El Salvador          Bajo
# 2               3  Aseguradora 3  El Salvador           NaN
# 3               4  Aseguradora 4   Costa Rica         Medio
# 4               5  Aseguradora 5   ElSalvador             B

# %%
df.shape

df.columns

df.info()

df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id_aseguradora  15 non-null     int64
#  1   nombre          15 non-null     object
#  2   pais            13 non-null     object
#  3   rating_riesgo   12 non-null     object
# dtypes: int64(1), object(3)
# memory usage: 612.0+ bytes
# id_aseguradora    0
# nombre            0
# pais              2
# rating_riesgo     3
# dtype: int64

# %%
def limpiar_dataframe(df):



    df.columns = df.columns.str.strip().str.lower()



    for col in df.select_dtypes(include='object').columns:

        df[col] = df[col].astype(str).str.strip()



    df = df.replace(r'^\s*$', pd.NA, regex=True)



    df = df.drop_duplicates()



    return df

# %%
df['rating_riesgo'] = df['rating_riesgo'].replace({
    'B': 'Bajo',
    'D': 'Bajo'
})

# %%
df['rating_riesgo'] = df['rating_riesgo'].fillna('Sin clasificación')

# %%
df['pais'] = df['pais'].replace({
    'ElSalvador': 'El Salvador'
})

# %%
df.head(15)
# Out:
#     id_aseguradora          nombre                 pais      rating_riesgo
# 0                1   Aseguradora 1           Costa Rica               Alto
# 1                2   Aseguradora 2          El Salvador               Bajo
# 2                3   Aseguradora 3          El Salvador  Sin clasificación
# 3                4   Aseguradora 4           Costa Rica              Medio
# 4                5   Aseguradora 5          El Salvador               Bajo
# 5                6   Aseguradora 6  Sin pais Registrado              Medio
# 6                7   Aseguradora 7            Guatemala               Alto
# 7                8   Aseguradora 8               Panamá               Bajo
# 8                9   Aseguradora 9  Sin pais Registrado               Bajo
# 9               10  Aseguradora 10               Panamá  Sin clasificación
# 10              11  Aseguradora 11             Honduras               Bajo
# ...

# %%
df['pais'] = df['pais'].fillna('Sin pais Registrado')

# %%
df = df.drop_duplicates()

# %%
df.columns = df.columns.str.strip().str.lower()

for col in df.select_dtypes(include='object'):
    df[col] = df[col].str.strip()

# %%
df.head(15)
# Out:
#     id_aseguradora          nombre                 pais      rating_riesgo
# 0                1   Aseguradora 1           Costa Rica               Alto
# 1                2   Aseguradora 2          El Salvador               Bajo
# 2                3   Aseguradora 3          El Salvador  Sin clasificación
# 3                4   Aseguradora 4           Costa Rica              Medio
# 4                5   Aseguradora 5          El Salvador               Bajo
# 5                6   Aseguradora 6  Sin pais Registrado              Medio
# 6                7   Aseguradora 7            Guatemala               Alto
# 7                8   Aseguradora 8               Panamá               Bajo
# 8                9   Aseguradora 9  Sin pais Registrado               Bajo
# 9               10  Aseguradora 10               Panamá  Sin clasificación
# 10              11  Aseguradora 11             Honduras               Bajo
# ...
